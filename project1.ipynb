# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
from sklearn import datasets
import seaborn as sns

# %%
dataset=pd.read_csv('diabetes.csv')
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0              6      148             72             35        0  33.6  \
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dataset.isnull().sum() #no null values
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
dataset.keys()
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
dataset.describe()  #used to get the central tendencies of our dataset
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin
# count   768.000000  768.000000     768.000000     768.000000  768.000000  \
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
dataset.corr()  #gives us a correlation matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672  \
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction
# Pregnancies              -0.073535  0.017683                 -0.033523  \
# ...

# %%
plt.figure(figsize=(10,8))#just to set the dimensions/size of the figure which its showing
sns.heatmap(dataset.corr(),annot=True,cmap='YlGnBu')
plt.title("Correlation Heatmap")
plt.show()

# %%
#kde plot
kde_plot=sns.kdeplot(dataset['Pregnancies'][dataset['Outcome']==1], color='Red', shade=True)
kde_plot=sns.kdeplot(dataset['Pregnancies'][dataset['Outcome']==0], color='Blue', shade=True)
kde_plot.set_xlabel('Pregnancies')
kde_plot.set_ylabel('Density')
kde_plot.set_title('Pregnancies Distribution')
kde_plot.legend(['Positive','Negative'])
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3264\1502908822.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kde_plot=sns.kdeplot(dataset['Pregnancies'][dataset['Outcome']==1], color='Red', shade=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_3264\1502908822.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kde_plot=sns.kdeplot(dataset['Pregnancies'][dataset['Outcome']==0], color='Blue', shade=True)

# %%
#violin plot
violin=sns.violinplot(data=dataset,x='Outcome',y='Glucose',split=True,linewidth=2,inner='quart')
violin.set_title('Glucose distribution')
# Out:
# Text(0.5, 1.0, 'Glucose distribution')

# %%
#kde plot
kde_plot=sns.kdeplot(dataset['Glucose'][dataset['Outcome']==1], color='Red', shade=True)
kde_plot=sns.kdeplot(dataset['Glucose'][dataset['Outcome']==0], color='Blue', shade=True)
kde_plot.set_xlabel('Glucose')
kde_plot.set_ylabel('Density')
kde_plot.set_title('Glucose Distribution')
kde_plot.legend(['Positive','Negative'])
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3264\575280654.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kde_plot=sns.kdeplot(dataset['Glucose'][dataset['Outcome']==1], color='Red', shade=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_3264\575280654.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   kde_plot=sns.kdeplot(dataset['Glucose'][dataset['Outcome']==0], color='Blue', shade=True)

# %%
#glucose
dataset['Glucose']=dataset['Glucose'].replace(0, dataset['Glucose'].median())
#BP
dataset['Glucose']=dataset['Glucose'].replace(0, dataset['Glucose'].median())
#Insulin
dataset['Insulin']=dataset['Insulin'].replace(0, dataset['Insulin'].mean())
#Skin thickness
dataset['SkinThickness']=dataset['SkinThickness'].replace(0, dataset['SkinThickness'].mean())
#BMI
dataset['BMI']=dataset['BMI'].replace(0, dataset['BMI'].mean())
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI
# 0              6      148             72      35.000000   79.799479  33.6  \
# 1              1       85             66      29.000000   79.799479  26.6
# 2              8      183             64      20.536458   79.799479  23.3
# 3              1       89             66      23.000000   94.000000  28.1
# 4              0      137             40      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10      101             76      48.000000  180.000000  32.9
# 764            2      122             70      27.000000   79.799479  36.8
# 765            5      121             72      23.000000  112.000000  26.2
# 766            1      126             60      20.536458   79.799479  30.1
# 767            1       93             70      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
X=dataset.drop(['Outcome'],axis=1)
Y=dataset['Outcome']
print(X)
print(Y)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI
# 0              6      148             72      35.000000   79.799479  33.6  \
# 1              1       85             66      29.000000   79.799479  26.6
# 2              8      183             64      20.536458   79.799479  23.3
# 3              1       89             66      23.000000   94.000000  28.1
# 4              0      137             40      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10      101             76      48.000000  180.000000  32.9
# 764            2      122             70      27.000000   79.799479  36.8
# 765            5      121             72      23.000000  112.000000  26.2
# 766            1      126             60      20.536458   79.799479  30.1
# 767            1       93             70      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y)
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI
# 449            0      120             74      18.000000   63.000000  30.5  \
# 551            3       84             68      30.000000  106.000000  31.9
# 424            8      151             78      32.000000  210.000000  42.9
# 232            1       79             80      25.000000   37.000000  25.4
# 597            1       89             24      19.000000   25.000000  27.8
# ..           ...      ...            ...            ...         ...   ...
# 757            0      123             72      20.536458   79.799479  36.3
# 358           12       88             74      40.000000   54.000000  35.3
# 278            5      114             74      20.536458   79.799479  24.9
# 71             5      139             64      35.000000  140.000000  28.6
# 478            8      126             74      38.000000   75.000000  25.9
#
#      DiabetesPedigreeFunction  Age
# 449                     0.285   26
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
training_accuracy=[]
test_accuracy=[]
for n in range (1,11):

 knn=KNeighborsClassifier(n_neighbors=n)
 knn.fit(X_train,y_train)
 training_accuracy.append(knn.score(X_train,y_train))
 test_accuracy.append(knn.score(X_test,y_test))   #knn.score returns us the mean accuracy

print(training_accuracy)
print(test_accuracy)
# Out:
# [1.0, 0.8385416666666666, 0.8454861111111112, 0.8125, 0.8038194444444444, 0.7881944444444444, 0.7934027777777778, 0.7829861111111112, 0.7847222222222222, 0.7725694444444444]
# [0.6770833333333334, 0.6927083333333334, 0.65625, 0.703125, 0.6875, 0.7291666666666666, 0.7135416666666666, 0.7447916666666666, 0.7239583333333334, 0.7395833333333334]

# %%
plt.plot(range(1,11),training_accuracy,label='training accuracy')
plt.plot(range(1,11),test_accuracy,label='test accuracy')
plt.xlabel('Accuracy')
plt.ylabel('n_neigbours')
plt.legend() #this statement helps us to print up the topic of each graph which is being depicted by it

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(random_state=0,max_depth=6)
dt.fit(X_train,y_train)
print(dt.score(X_test,y_test))
print(dt.score(X_train,y_train))
# Out:
# 0.7135416666666666
# 0.8663194444444444

# %%
from sklearn.neural_network import MLPClassifier
mlp=MLPClassifier(random_state=42)
mlp.fit(X_train,y_train)
print(mlp.score(X_test,y_test))
print(mlp.score(X_train,y_train))
# Out:
# 0.6822916666666666
# 0.7517361111111112

# %%
#scaling
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
X_scale_train=sc.fit_transform(X_train)
Y_scale_train=sc.fit_transform([y_train])
